# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    🔥🔥TEXT-TRANSLATION||TRANSFORMERS||T5🔥🔥
# </div>

# %% [markdown]
# ![Image](https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Google_2015_logo.svg/800px-Google_2015_logo.svg.png)

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨LLM - T5✨✨
# </div>

# %% [markdown]
# Here's some information about the LLM T5 model using bullets and sub-bullets:
#
# - **LLM T5 Model Overview**
#   - The Large Language Model (LLM) T5 is a state-of-the-art natural language processing (NLP) model developed by Google Research.
#   - It belongs to the T5 (Text-to-Text Transfer Transformer) family of models, known for their versatility and high performance across various NLP tasks.
#
# - **Key Features and Capabilities**
#   - **Text Generation:** LLM T5 excels in generating coherent and contextually relevant text across a wide range of topics and styles.
#   - **Translation:** It supports multilingual translation tasks, allowing seamless conversion between different languages with high accuracy.
#   - **Summarization:** The model is capable of summarizing large volumes of text into concise and meaningful summaries, preserving key information.
#   - **Question Answering:** LLM T5 can answer questions based on provided context, demonstrating strong comprehension and reasoning abilities.
#   - **Sentence Completion:** It can fill in missing words or complete sentences based on the surrounding text, making it useful for various language generation tasks.
#
# - **Training and Architecture**
#   - LLM T5 is trained using a large-scale dataset and leverages the Transformer architecture, specifically the encoder-decoder Transformer model.
#   - It benefits from pretraining on diverse text corpora, fine-tuning on specific tasks, and transfer learning techniques, resulting in robust performance.
#
# - **Applications and Use Cases**
#   - **Content Generation:** Ideal for generating articles, stories, product descriptions, and other textual content in multiple languages.
#   - **Language Translation Services:** Used in translation platforms and applications for accurate and efficient language conversion.
#   - **Text Summarization:** Employed in summarization tools for condensing lengthy documents, news articles, and research papers.
#   - **Chatbots and Conversational AI:** Integrated into chatbot systems to facilitate natural and engaging conversations with users.
#
# - **Future Developments**
#   - Ongoing research and development efforts aim to enhance the capabilities of LLM T5 further, including improved contextual understanding, better handling of ambiguous phrases, and scalability for larger datasets.
#   - Collaboration with the NLP community and continuous model refinement are key aspects of advancing LLM T5's performance and versatility in real-world applications.

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨TRANSLATION || LLM || T5✨✨
# </div>

# %% [markdown]
# ![](https://images.datalanguage.com/377KJaaaPvZ7CTRtqF4mQM/large-language-model-ai.jpg)

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨TRANSLATION || English 2 French✨✨
# </div>

# %%
from transformers import pipeline

def translate_text_t5(prompt):
    translator = pipeline('translation_en_to_fr', model='t5-small')
    translated_text = translator(prompt, max_length=100)[0]['translation_text']
    print(translated_text)
# Out:
# 2024-03-28 15:56:53.530822: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 15:56:53.530959: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 15:56:53.718828: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
prompt_text = "Translate the following sentence into French: Hello, how are you?"
translate_text_t5(prompt_text)
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Traduire la phrase suivante en français : Bonjour, comment êtes-vous?

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨TRANSLATION || English 2 Hindi✨✨
# </div>

# %%
def translate_text_english_to_hindi(prompt):
    translator = pipeline('translation_en_to_hi', model='Helsinki-NLP/opus-mt-en-hi')
    translated_text = translator(prompt, max_length=100)[0]['translation_text']
    print(translated_text)

# %%
english_text = "Hello, how are you?"
translate_text_english_to_hindi(english_text)
# Out:
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
# ...

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨TRANSLATION ||Hindi 2 English✨✨
# </div>

# %%
def translate_text_hindi_to_english(prompt):
    translator = pipeline('translation_hi_to_en', model='Helsinki-NLP/opus-mt-hi-en')
    translated_text = translator(prompt, max_length=100)[0]['translation_text']
    print(translated_text)

# %%
hindi_text = "नमस्ते, आप कैसे हैं?"

translate_text_hindi_to_english(hindi_text)
# Out:
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/304M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/813k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# Hello, how are you?

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨TRANSLATION || Spanish 2 English✨✨
# </div>

# %%
def translate_text_spanish_to_english(prompt):
    translator = pipeline('translation_es_to_en', model='Helsinki-NLP/opus-mt-es-en')
    translated_text = translator(prompt, max_length=100)[0]['translation_text']
    print(translated_text)

# %%
spanish_text = "Hola, ¿cómo estás?"
translate_text_spanish_to_english(spanish_text)
# Out:
# config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Hey, how are you?

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨TRANSLATION || German 2 English✨✨
# </div>

# %%
def translate_text_german_to_english(prompt):
    translator = pipeline('translation_de_to_en', model='Helsinki-NLP/opus-mt-de-en')
    translated_text = translator(prompt, max_length=100)[0]['translation_text']
    print(translated_text)

# %%
german_text = "Guten Tag, wie geht es Ihnen?"
translate_text_german_to_english(german_text)
# Out:
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# Hello, how are you?

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨TRANSLATION || French 2 English✨✨
# </div>

# %%
def translate_text_french_to_english(prompt):
    translator = pipeline('translation_fr_to_en', model='Helsinki-NLP/opus-mt-fr-en')
    translated_text = translator(prompt, max_length=100)[0]['translation_text']
    print(translated_text)

# %%
french_text = "Bonjour, comment ça va?"
translate_text_french_to_english(french_text)
# Out:
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Hello, how are you?

# %% [markdown]
# <div style="color:white; background-color:#5642C5; padding: 10px; border-radius: 15px; font-size: 150%; font-family: Verdana; text-align:center; -webkit-text-stroke-width: 1px; -webkit-text-stroke-color: black; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">
#    ✨✨TRANSLATION || Chinese 2 English✨✨
# </div>

# %%
def translate_text_chinese_to_english(prompt):
    translator = pipeline('translation_zh_to_en', model='Helsinki-NLP/opus-mt-zh-en')
    translated_text = translator(prompt, max_length=100)[0]['translation_text']
    print(translated_text)

# %%
chinese_text = "你好，你最近怎么样？"
translate_text_chinese_to_english(chinese_text)
# Out:
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/807k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# Hello. How are you?

# %% [markdown]
# ![](https://www.pngitem.com/pimgs/m/151-1519293_clip-art-thank-you-sir-hd-png-download.png)
